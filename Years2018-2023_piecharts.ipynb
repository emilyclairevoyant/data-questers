# %%
import pandas as pd
import calplot
import numpy as np; np.random.seed(sum(map(ord, 'calplot')))
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#read my csv and make DF
#2018
path2018 = Path("Resources/daily_aqi_by_county_2018.csv")
data2018 = pd.read_csv(path2018)
aqi2018_df = pd.DataFrame(data2018)
#aqi2018_df.head()

#2019
path2019 = Path("Resources/daily_aqi_by_county_2019.csv")
data2019 = pd.read_csv(path2019)
aqi2019_df = pd.DataFrame(data2019)
#aqi2019_df.head()

#2020
path2020 = Path("Resources/daily_aqi_by_county_2020.csv")
data2020 = pd.read_csv(path2020)
aqi2020_df = pd.DataFrame(data2020)
#aqi2020_df.head()

#2021
path2021 = Path("Resources/daily_aqi_by_county_2021.csv")
data2021 = pd.read_csv(path2021)
aqi2021_df = pd.DataFrame(data2021)
#aqi2021_df.head()

#2022
path2022 = Path("Resources/daily_aqi_by_county_2022.csv")
data2022 = pd.read_csv(path2022)
aqi2022_df = pd.DataFrame(data2022)
#aqi2022_df.head()

#2023
path2023 = Path("Resources/daily_aqi_by_county_2023.csv")
data2023 = pd.read_csv(path2023)
aqi2023_df = pd.DataFrame(data2023)
aqi2023_df.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2023-01-10   35     Good
# 1    Alabama     Baldwin           1            3  2023-01-11   28     Good
# 2    Alabama     Baldwin           1            3  2023-01-12   23     Good
# 3    Alabama     Baldwin           1            3  2023-01-13   18     Good
# 4    Alabama     Baldwin           1            3  2023-01-14   20     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
#only nj data
#2018
aqi2018nj_df = aqi2018_df[aqi2018_df['State Name'] == 'New Jersey']
#aqi2018nj_df.head()

#2019
aqi2019nj_df = aqi2019_df[aqi2019_df['State Name'] == 'New Jersey']
#aqi2019nj_df.head()

#2020
aqi2020nj_df = aqi2020_df[aqi2020_df['State Name'] == 'New Jersey']
#aqi2020nj_df.head()

#2021
aqi2021nj_df = aqi2021_df[aqi2021_df['State Name'] == 'New Jersey']
#aqi2021nj_df.head()

#2022
aqi2022nj_df = aqi2022_df[aqi2020_df['State Name'] == 'New Jersey']
#aqi2022nj_df.head()

#2023
aqi2023nj_df = aqi2023_df[aqi2023_df['State Name'] == 'New Jersey']
aqi2023nj_df.head()
# Out:
# C:\Users\musam\AppData\Local\Temp\ipykernel_29276\2923651022.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   aqi2022nj_df = aqi2022_df[aqi2020_df['State Name'] == 'New Jersey']
#        State Name county Name  State Code  County Code        Date  AQI  \
# 98856  New Jersey    Atlantic          34            1  2023-01-01   25
# 98857  New Jersey    Atlantic          34            1  2023-01-02   43
# 98858  New Jersey    Atlantic          34            1  2023-01-03   50
# 98859  New Jersey    Atlantic          34            1  2023-01-04   32
# 98860  New Jersey    Atlantic          34            1  2023-01-05   18
#
#       Category Defining Parameter Defining Site  Number of Sites Reporting
# 98856     Good              Ozone   34-001-0006                          1
# 98857     Good              PM2.5   34-001-0006                          1
# 98858     Good              PM2.5   34-001-0006                          1
# 98859     Good              PM2.5   34-001-0006                          1
# 98860     Good              Ozone   34-001-0006                          1

# %%
#merge datasets (optional??)
#example: blah = pd.merge(study_results, mouse_metadata, on=["Mouse ID"], how="left")

# %%
#clean data

# %%
#clean for pie chart
##counts for 2018 nj
days2018_count = aqi2018nj_df["Category"].value_counts()
print(days2018_count)

#counts for 2019
days2019_count = aqi2019nj_df["Category"].value_counts()
print(days2019_count)

#counts for 2020
days2020_count = aqi2020nj_df["Category"].value_counts()
print(days2020_count)

#counts for 2021
days2021_count = aqi2021nj_df["Category"].value_counts()
print(days2021_count)

#counts for 2022
days2022_count = aqi2022nj_df["Category"].value_counts()
print(days2022_count)

#counts for 2023
days2023_count = aqi2023nj_df["Category"].value_counts()
print(days2023_count)

# Replace NaN values with 0 in each of the Series or DataFrames
days2018_count = days2018_count.fillna(0)
days2019_count = days2019_count.fillna(0)
days2020_count = days2020_count.fillna(0)
days2021_count = days2021_count.fillna(0)
days2022_count = days2022_count.fillna(0)
days2023_count = days2023_count.fillna(0)
# Out:
# Category
# Good                              4296
# Moderate                          1134
# Unhealthy for Sensitive Groups      67
# Unhealthy                            8
# Name: count, dtype: int64
# Category
# Good                              4392
# Moderate                          1097
# Unhealthy for Sensitive Groups      25
# Name: count, dtype: int64
# Category
# Good                              4758
# Moderate                           704
# Unhealthy for Sensitive Groups      10
# Name: count, dtype: int64
# Category
# Good                              4534
# Moderate                           956
# Unhealthy for Sensitive Groups      44
# Unhealthy                            1
# Name: count, dtype: int64
# Category
# Good                              4538
# Moderate                           914
# Unhealthy for Sensitive Groups      16
# Unhealthy                            3
# Hazardous                            1
# Name: count, dtype: int64
# Category
# Good                              2073
# Moderate                           465
# Unhealthy                           44
# Unhealthy for Sensitive Groups      42
# Very Unhealthy                       5
# Name: count, dtype: int64

# %%
#counts for 2018 to 2023
# Concatenate the DataFrames
#combined_counts = pd.concat([days2018_count, days2019_count, days2020_count, days2021_count, days2022_count, days2023_count], axis=1)
#print(combined_counts)
days18to23=(days2018_count)+(days2019_count)+(days2020_count)+(days2021_count)+(days2022_count)+(days2023_count)
days18to23 = days18to23.fillna(0)
print(days18to23)
# Out:
# Category
# Good                              24591.0
# Hazardous                             0.0
# Moderate                           5270.0
# Unhealthy                             0.0
# Unhealthy for Sensitive Groups      204.0
# Very Unhealthy                        0.0
# Name: count, dtype: float64

# %%
# Generate a pie chart for day category 2018-2023
labels = ['Good','Moderate','Unhealthy','Unhealthy for Sensitive Groups','Very Unhealthy','Hazardous']
colors = ['lightgreen','orange','lightpink','red','coral','navy']
explode_all = (0, 0.1, 0, 0, 0.4, 0.7) 
#days18to23.plot(kind='pie', labels=labels, colors =colors, legend = True, autopct='%2.2f%%')
#plt.pie(days18to23,labels=labels,colors=colors,autopct='%2.2f%%')
plt.pie(days18to23,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_all)
plt.title('Category of Days 2018-2023')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

#pie chart 2018
explode_2018=(0, 0, 0, 0.4)
plt.pie(days2018_count,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_2018)
plt.title('Category of Days 2018')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

#pie chart 2019
explode_2019=(0, 0, 0.2)
plt.pie(days2019_count,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_2019)
plt.title('Category of Days 2019')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

#pie chart 2020
explode_2020=(0, 0, 0.2)
plt.pie(days2020_count,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_2020)
plt.title('Category of Days 2020')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

#pie chart 2021
explode_2021=(0, 0, 0.4, 0.8)
plt.pie(days2021_count,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_2021)
plt.title('Category of Days 2021')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

#pie chart 2022
explode_2022=(0, 0, 0, 0.5, 1)
plt.pie(days2022_count,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_2022)
plt.title('Category of Days 2022')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

#pie chart 2023
explode_2023=(0, 0, 0, 0, 0.4)
plt.pie(days2023_count,labels=None,colors=colors,autopct='%2.2f%%', pctdistance=1.20, explode=explode_2023)
plt.title('Category of Days 2023')
# Move the legend to a specific position
plt.legend(labels=labels,loc='upper right', bbox_to_anchor=(1.75, 1))
plt.show()

# %%
#are good days increasing/decreasing? - line plot over time?
#not full 265 for 2023 and pot wildfires
years = [2018, 2019, 2020, 2021, 2022, 2023]
#print(days2021_count.iloc[0]) - good days
plt.plot(years, [days2018_count.iloc[0], days2019_count.iloc[0], days2020_count.iloc[0], days2021_count.iloc[0], days2022_count.iloc[0], days2023_count.iloc[0]], marker='o', color='b', linestyle='-', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Good Days Over Time')
plt.grid(True)
plt.show()

# %%
#moderate days over time

plt.plot(years, [days2018_count.iloc[1], days2019_count.iloc[1], days2020_count.iloc[1], days2021_count.iloc[1], days2022_count.iloc[1], days2023_count.iloc[1]], marker='o', color='b', linestyle='-', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Moderate Days Over Time')
plt.grid(True)
plt.show()

# %%
#unhealthy for sensitive days over time

plt.plot(years, [days2018_count.iloc[2], days2019_count.iloc[2], days2020_count.iloc[2], days2021_count.iloc[2], days2022_count.iloc[2], days2023_count.iloc[3]], marker='o', color='b', linestyle='-', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Unhealthy for Sensitive Groups Days Over Time')
plt.grid(True)
plt.show()

# %%
#unhealthy days over time

plt.plot(years, [days2018_count.iloc[3], 0, 0, days2021_count.iloc[3], days2022_count.iloc[3], days2023_count.iloc[2]], marker='o', color='b', linestyle='-', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Unhealthy Days Over Time')
plt.grid(True)
plt.show()

# %%
#very unhealthy days over time
plt.plot(years, [0, 0, 0, 0, 0, days2023_count.iloc[4]], marker='o', color='b', linestyle='-', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Very Unhealthy Days Over Time')
plt.grid(True)
plt.show()

# %%
#hazardous over time
plt.plot(years, [0, 0, 0, 0, days2022_count.iloc[4], 0], marker='o', color='b', linestyle='-', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Hazardous Days Over Time')
plt.grid(True)
plt.show()

# %%
#can do breakdown per counties of interest
#merge years df by county
merged_df = pd.merge(aqi2018nj_df, aqi2019nj_df, on="county Name", how = 'left')
merged_df = pd.merge(merged_df, aqi2021nj_df, on="county Name", how = 'left')
merged_df.head()
#merged_df = pd.merge(merged_df, aqi2022nj_df, on="county Name")
#merged_df = pd.merge(merged_df, aqi2023nj_df, on="county Name")

# Prepare data for plotting
# You may need to pivot the data or reshape it as needed for plotting

# Plotting
#plt.figure(figsize=(12, 6))
#for county in merged_df['county'].unique():
    #county_data = merged_df[merged_df['county'] == county]
    #plt.plot(county_data['year'], county_data['air_quality_score'], label=county)

#plt.xlabel('Year')
#plt.ylabel('Air Quality Score')
#plt.title('Air Quality Score Over 5-Year Period by County')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[19], line 4
#       1 #can do breakdown per counties of interest
#       2 #merge years df by county
#       3 merged_df = pd.merge(aqi2018nj_df, aqi2019nj_df, on="county Name", how = 'left')
# ----> 4 merged_df = pd.merge(merged_df, aqi2021nj_df, on="county Name", how = 'left')
#       5 merged_df.head()
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:1151, in _MergeOperation._get_join_info(self)
#    1147     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1148         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1149     )
#    1150 else:
# -> 1151     (left_indexer, right_indexer) = self._get_join_indexers()
#    1153     if self.right_index:
#    1154         if len(self.left) > 0:
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:1125, in _MergeOperation._get_join_indexers(self)
#    1123 # make mypy happy
#    1124 assert self.how != "asof"
# -> 1125 return get_join_indexers(
#    1126     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1127 )
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:1759, in get_join_indexers(left_keys, right_keys, sort, how)
#    1757     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    1758 else:
# -> 1759     lidx, ridx = get_join_indexers_non_unique(
#    1760         left._values, right._values, sort, how
#    1761     )
#    1763 if lidx is not None and is_range_indexer(lidx, len(left)):
#    1764     lidx = None
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:1795, in get_join_indexers_non_unique(left, right, sort, how)
#    1793 lkey, rkey, count = _factorize_keys(left, right, sort=sort)
#    1794 if how == "left":
# -> 1795     lidx, ridx = libjoin.left_outer_join(lkey, rkey, count, sort=sort)
#    1796 elif how == "right":
#    1797     ridx, lidx = libjoin.left_outer_join(rkey, lkey, count, sort=sort)
#
# File join.pyx:154, in pandas._libs.join.left_outer_join()
#
# File algos.pyx:240, in pandas._libs.algos.groupsort_indexer()
#
# MemoryError: Unable to allocate 5.06 GiB for an array with shape (678502041,) and data type int64

# %%
#stacked line graph 2018-2025 - MUST FIX SINCE DROPPED NAs --> INDEXES ARE DIFFERENT NOW
#combined_counts = {"2018": [days2018_count],
#                  "2019": [days2019_count],
#                  "2020": [days2020_count],
#                  "2021": [days2021_count],
#                  "2022": [days2022_count],
#                  "2023": [days2023_count]}

combined_counts = [days2018_count, days2019_count, days2020_count, days2021_count, days2022_count, days2023_count]
print(combined_counts)
#print(combined_counts[0][0]) #this is good for 2018; 1=mod, 2= unhth for sen, 3=unhth, 4=v unheath, 5=haz
#df = pd.DataFrame(combined_counts)
#print(df.head())

# Plot a stacked line plot
labels_stacked = ["Good","Moderate","Unhealthy for Sensitive","Unhealthy","Very Unhealthy","Hazardous"]
plt.plot(years, [combined_counts[0][0], combined_counts[1][0], combined_counts[2][0], combined_counts[3][0], combined_counts[4][0], combined_counts[5][0]], marker='o', color='b', linestyle='-', linewidth=2)
plt.plot(years, [combined_counts[0][1], combined_counts[1][1], combined_counts[2][1], combined_counts[3][1], combined_counts[4][1], combined_counts[5][1]], marker='o', color='r', linestyle='-', linewidth=2)
plt.plot(years, [combined_counts[0][2], combined_counts[1][2], combined_counts[2][2], combined_counts[3][2], combined_counts[4][2], combined_counts[5][2]], marker='o', color='g', linestyle='-', linewidth=2)
plt.plot(years, [combined_counts[0][3], combined_counts[1][3], combined_counts[2][3], combined_counts[3][3], combined_counts[4][3], combined_counts[5][3]], marker='o', color='k', linestyle='-', linewidth=2)
plt.plot(years, [combined_counts[0][4], combined_counts[1][4], combined_counts[2][4], combined_counts[3][4], combined_counts[4][4], combined_counts[5][4]], marker='o', color='c', linestyle='-', linewidth=2)
plt.plot(years, [combined_counts[0][5], combined_counts[1][5], combined_counts[2][5], combined_counts[3][5], combined_counts[4][5], combined_counts[5][5]], marker='o', color='m', linestyle='-', linewidth=2)
plt.legend(labels=labels_stacked)
plt.title("Category of Days 2018-2023")
plt.ylabel("Count")

#plt.plot(years, combined_counts[0][0], marker='o', color='b', linestyle='-', linewidth=2)
#plt.plot(years, combined_counts[1][0], marker='o', color='r', linestyle='-', linewidth=2)
#plt.plot(years, combined_counts[2][0], marker='o', color='g', linestyle='-', linewidth=2)
#plt.plot(years, combined_counts[3][0], marker='o', color='c', linestyle='-', linewidth=2)
#plt.plot(years, combined_counts[4][0], marker='o', color='m', linestyle='-', linewidth=2)
#plt.plot(years, combined_counts[5][0], marker='o', color='k', linestyle='-', linewidth=2)

#plt.plot(years, combined_counts["2018"], marker='o', color='b', linestyle='-', linewidth=2)
#plt.plot(years, combined_counts["2019"], [])
#combined_counts["2020"],combined_counts["2021"],combined_counts["2022"],combined_counts["2023"]
#df.plot(kind='line', stacked=True)
#plt.xticks(rotation=90)
plt.show()
# Out:
# [Category
# Good                              4296
# Moderate                          1134
# Unhealthy for Sensitive Groups      67
# Unhealthy                            8
# Name: count, dtype: int64, Category
# Good                              4392
# Moderate                          1097
# Unhealthy for Sensitive Groups      25
# Name: count, dtype: int64, Category
# Good                              4758
# Moderate                           704
# Unhealthy for Sensitive Groups      10
# Name: count, dtype: int64, Category
# Good                              4534
# Moderate                           956
# Unhealthy for Sensitive Groups      44
# Unhealthy                            1
# Name: count, dtype: int64, Category
# Good                              4538
# Moderate                           914
# Unhealthy for Sensitive Groups      16
# Unhealthy                            3
# Hazardous                            1
# Name: count, dtype: int64, Category
# Good                              2073
# Moderate                           465
# Unhealthy                           44
# Unhealthy for Sensitive Groups      42
# Very Unhealthy                       5
# Name: count, dtype: int64]
# C:\Users\musam\AppData\Local\Temp\ipykernel_6752\2937489227.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(years, [combined_counts[0][0], combined_counts[1][0], combined_counts[2][0], combined_counts[3][0], combined_counts[4][0], combined_counts[5][0]], marker='o', color='b', linestyle='-', linewidth=2)
# C:\Users\musam\AppData\Local\Temp\ipykernel_6752\2937489227.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(years, [combined_counts[0][1], combined_counts[1][1], combined_counts[2][1], combined_counts[3][1], combined_counts[4][1], combined_counts[5][1]], marker='o', color='r', linestyle='-', linewidth=2)
# C:\Users\musam\AppData\Local\Temp\ipykernel_6752\2937489227.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(years, [combined_counts[0][2], combined_counts[1][2], combined_counts[2][2], combined_counts[3][2], combined_counts[4][2], combined_counts[5][2]], marker='o', color='g', linestyle='-', linewidth=2)
# C:\Users\musam\AppData\Local\Temp\ipykernel_6752\2937489227.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(years, [combined_counts[0][3], combined_counts[1][3], combined_counts[2][3], combined_counts[3][3], combined_counts[4][3], combined_counts[5][3]], marker='o', color='k', linestyle='-', linewidth=2)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 20
#      18 plt.plot(years, [combined_counts[0][1], combined_counts[1][1], combined_counts[2][1], combined_counts[3][1], combined_counts[4][1], combined_counts[5][1]], marker='o', color='r', linestyle='-', linewidth=2)
#      19 plt.plot(years, [combined_counts[0][2], combined_counts[1][2], combined_counts[2][2], combined_counts[3][2], combined_counts[4][2], combined_counts[5][2]], marker='o', color='g', linestyle='-', linewidth=2)
# ---> 20 plt.plot(years, [combined_counts[0][3], combined_counts[1][3], combined_counts[2][3], combined_counts[3][3], combined_counts[4][3], combined_counts[5][3]], marker='o', color='k', linestyle='-', linewidth=2)
#      21 plt.plot(years, [combined_counts[0][4], combined_counts[1][4], combined_counts[2][4], combined_counts[3][4], combined_counts[4][4], combined_counts[5][4]], marker='o', color='c', linestyle='-', linewidth=2)
#      22 plt.plot(years, [combined_counts[0][5], combined_counts[1][5], combined_counts[2][5], combined_counts[3][5], combined_counts[4][5], combined_counts[5][5]], marker='o', color='m', linestyle='-', linewidth=2)
#
# File ~\anaconda3\envs\pythondata\lib\site-packages\pandas\core\series.py:1118, in Series.__getitem__(self, key)
#    1108 if is_integer(key) and self.index._should_fallback_to_positional:
#    1109     warnings.warn(
#    1110         # GH#50617
#    1111         "Series.__getitem__ treating keys as positions is deprecated. "
#    (...)
#    1116         stacklevel=find_stack_level(),
#    1117     )
# -> 1118     return self._values[key]
#    1120 elif key_is_scalar:
#    1121     return self._get_value(key)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
#explore over season or just looks at calplot to see groupings of days?
